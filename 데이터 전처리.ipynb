# %%
import pandas as pd

# %%
situation_df = pd.read_csv(r'C:\Users\GT1030\hitters_situation.csv',engine='python')
total_df = pd.read_csv(r'C:\Users\GT1030\hitters_total.csv',engine='python')
total_df.head()
# Out:
#    팀명     이름    연도    AVG    G   PA   AB    R    H  2B  ...  RBI  SB CS  BB  \
# 0  두산  페르난데스  2018      -    -    -    -    -    -   -  ...    -   -  -   -
# 1  두산  페르난데스  2019  0.344  144  645  572   87  197  34  ...   88   1  2  61
# 2  두산  페르난데스  2020  0.340  144  668  586  104  199  29  ...  105   0  1  58
# 3  두산    허경민  2018  0.324  133  577  516   85  167  30  ...   79  20  4  32
# 4  두산    허경민  2019  0.288  133  540  475   71  137  25  ...   60  11  5  34
#
#   HBP  SO GDP    SLG    OBP  E
# 0   -   -   -      -      -  -
# 1   6  54  16  0.483  0.409  3
# 2  13  42  26  0.497  0.404  1
# 3  16  52  15  0.459  0.376  7
# 4  17  36  16  0.371  0.350  8
#
# [5 rows x 23 columns]

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   팀명      912 non-null    object
#  1   이름      912 non-null    object
#  2   연도      912 non-null    int64
#  3   AVG     912 non-null    object
#  4   G       912 non-null    object
#  5   PA      912 non-null    object
#  6   AB      912 non-null    object
#  7   R       912 non-null    object
#  8   H       912 non-null    object
#  9   2B      912 non-null    object
#  10  3B      912 non-null    object
#  11  HR      912 non-null    object
#  12  TB      912 non-null    object
#  13  RBI     912 non-null    object
#  14  SB      912 non-null    object
#  15  CS      912 non-null    object
#  16  BB      912 non-null    object
#  17  HBP     912 non-null    object
#  18  SO      912 non-null    object
#  19  GDP     912 non-null    object
#  20  SLG     912 non-null    object
# ...

# %%
total_df = total_df.replace('-',pd.NaT)
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   팀명      912 non-null    object
#  1   이름      912 non-null    object
#  2   연도      912 non-null    int64
#  3   AVG     645 non-null    object
#  4   G       694 non-null    object
#  5   PA      694 non-null    object
#  6   AB      694 non-null    object
#  7   R       694 non-null    object
#  8   H       694 non-null    object
#  9   2B      694 non-null    object
#  10  3B      694 non-null    object
#  11  HR      694 non-null    object
#  12  TB      694 non-null    object
#  13  RBI     694 non-null    object
#  14  SB      694 non-null    object
#  15  CS      694 non-null    object
#  16  BB      694 non-null    object
#  17  HBP     694 non-null    object
#  18  SO      694 non-null    object
#  19  GDP     694 non-null    object
#  20  SLG     645 non-null    object
# ...

# %%
total_df.head(30)
# Out:
#     팀명     이름    연도    AVG    G   PA   AB    R    H   2B  ...  RBI   SB   CS  \
# 0   두산  페르난데스  2018    NaT  NaT  NaT  NaT  NaT  NaT  NaT  ...  NaT  NaT  NaT
# 1   두산  페르난데스  2019  0.344  144  645  572   87  197   34  ...   88    1    2
# 2   두산  페르난데스  2020  0.340  144  668  586  104  199   29  ...  105    0    1
# 3   두산    허경민  2018  0.324  133  577  516   85  167   30  ...   79   20    4
# 4   두산    허경민  2019  0.288  133  540  475   71  137   25  ...   60   11    5
# 5   두산    허경민  2020  0.332  117  487  437   70  145   25  ...   58   14    6
# 6   두산    오재일  2018  0.279  123  477  401   69  112   19  ...   80    1    1
# 7   두산    오재일  2019  0.293  130  529  467   76  137   29  ...  102    2    1
# 8   두산    오재일  2020  0.312  127  534  471   62  147   32  ...   89    2    1
# 9   두산    최주환  2018  0.333  138  590  519   87  173   39  ...  108    1    0
# 10  두산    최주환  2019  0.277   87  325  285   27   79   13  ...   47    0    0
# ...

# %%
total_df = total_df.dropna().reset_index(drop=True)
total_df.head()
# Out:
#    팀명     이름    연도    AVG    G   PA   AB    R    H  2B  ...  RBI  SB CS  BB  \
# 0  두산  페르난데스  2019  0.344  144  645  572   87  197  34  ...   88   1  2  61
# 1  두산  페르난데스  2020  0.340  144  668  586  104  199  29  ...  105   0  1  58
# 2  두산    허경민  2018  0.324  133  577  516   85  167  30  ...   79  20  4  32
# 3  두산    허경민  2019  0.288  133  540  475   71  137  25  ...   60  11  5  34
# 4  두산    허경민  2020  0.332  117  487  437   70  145  25  ...   58  14  6  35
#
#   HBP  SO GDP    SLG    OBP  E
# 0   6  54  16  0.483  0.409  3
# 1  13  42  26  0.497  0.404  1
# 2  16  52  15  0.459  0.376  7
# 3  17  36  16  0.371  0.350  8
# 4   5  28  10  0.442  0.382  9
#
# [5 rows x 23 columns]

# %%
df_1 = total_df[total_df.columns[3:]].astype('float')

for i in df_1.columns:
    total_df[i] = df_1[i]
    
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   팀명      645 non-null    object
#  1   이름      645 non-null    object
#  2   연도      645 non-null    int64
#  3   AVG     645 non-null    float64
#  4   G       645 non-null    float64
#  5   PA      645 non-null    float64
#  6   AB      645 non-null    float64
#  7   R       645 non-null    float64
#  8   H       645 non-null    float64
#  9   2B      645 non-null    float64
#  10  3B      645 non-null    float64
#  11  HR      645 non-null    float64
#  12  TB      645 non-null    float64
#  13  RBI     645 non-null    float64
#  14  SB      645 non-null    float64
#  15  CS      645 non-null    float64
#  16  BB      645 non-null    float64
#  17  HBP     645 non-null    float64
#  18  SO      645 non-null    float64
#  19  GDP     645 non-null    float64
#  20  SLG     645 non-null    float64
# ...

# %%
situation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   팀명      912 non-null    object
#  1   이름      912 non-null    object
#  2   구분      912 non-null    object
#  3   AVG     912 non-null    object
#  4   AB      912 non-null    object
#  5   H       912 non-null    object
#  6   2B      912 non-null    object
#  7   3B      912 non-null    object
#  8   HR      912 non-null    object
#  9   RBI     912 non-null    object
#  10  BB      912 non-null    object
#  11  HBP     912 non-null    object
#  12  SO      912 non-null    object
#  13  GDP     912 non-null    object
# dtypes: object(14)
# memory usage: 99.9+ KB

# %%
situation_df = situation_df.replace('-',pd.NaT)
situation_df = situation_df.dropna().reset_index(drop=True)
df_1 = situation_df[situation_df.columns[3:]].astype('float')

for i in df_1.columns:
    situation_df[i] = df_1[i]
    
situation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   팀명      764 non-null    object
#  1   이름      764 non-null    object
#  2   구분      764 non-null    object
#  3   AVG     764 non-null    float64
#  4   AB      764 non-null    float64
#  5   H       764 non-null    float64
#  6   2B      764 non-null    float64
#  7   3B      764 non-null    float64
#  8   HR      764 non-null    float64
#  9   RBI     764 non-null    float64
#  10  BB      764 non-null    float64
#  11  HBP     764 non-null    float64
#  12  SO      764 non-null    float64
#  13  GDP     764 non-null    float64
# dtypes: float64(11), object(3)
# memory usage: 83.7+ KB

# %%
situation_df.head()
# Out:
#    팀명     이름    구분    AVG     AB      H    2B   3B    HR   RBI    BB  HBP  \
# 0  두산  페르난데스   좌투수  0.367  158.0   58.0   9.0  0.0   2.0  23.0  19.0  6.0
# 1  두산  페르난데스   우투수  0.330  373.0  123.0  16.0  0.0  17.0  72.0  35.0  5.0
# 2  두산  페르난데스  언더투수  0.327   55.0   18.0   4.0  0.0   2.0  10.0   4.0  2.0
# 3  두산    허경민   좌투수  0.383   94.0   36.0   9.0  0.0   1.0  10.0  12.0  1.0
# 4  두산    허경민   우투수  0.318  286.0   91.0  15.0  0.0   5.0  44.0  20.0  3.0
#
#      SO   GDP
# 0   7.0  14.0
# 1  29.0  11.0
# 2   6.0   1.0
# 3   4.0   3.0
# 4  22.0   6.0
