# %%
import pandas as pd

Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re180_Pr0_2.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)
Data.head(213)
# Out:
# (81620, 54)
#             X         Y    y_plus  wedge_height  Nu_t_lsq_n  \
# 0    0.000000  0.017326   3.11864             0    0.000008
# 1    0.000000  0.019721   3.54973             0    0.000011
# 2    0.000000  0.022172   3.99089             0    0.000016
# 3    0.000000  0.024680   4.44233             0    0.000022
# 4    0.000000  0.027246   4.90425             0    0.000028
# 5    0.000000  0.029872   5.37688             0    0.000037
# 6    0.000000  0.032558   5.86044             0    0.000046
# 7    0.000000  0.035306   6.35514             0    0.000058
# 8    0.000000  0.038118   6.86120             0    0.000071
# 9    0.000000  0.040994   7.37886             0    0.000085
# 10   0.000000  0.043935   7.90835             0    0.000102
# 11   0.000000  0.046944   8.44989             0    0.000121
# 12   0.000000  0.050021   9.00373             0    0.000141
# 13   0.000000  0.053167   9.57010             0    0.000164
# ...

# %%
c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(385):
    for j in range(106):
        c.loc[j+106*i] = (Data.loc[j+2*106*i] + Data.loc[211-j+2*106*i])/2
        c['Y'][j+106*i] = Data.loc[j+2*106*i][1]
c
# Out:
#              X         Y     y_plus  wedge_height  Nu_t_lsq_n  \
# 0       0.0000  0.017326    3.11864           0.0    0.000008
# 1       0.0000  0.019721    3.54973           0.0    0.000011
# 2       0.0000  0.022172    3.99089           0.0    0.000016
# 3       0.0000  0.024680    4.44233           0.0    0.000021
# 4       0.0000  0.027246    4.90425           0.0    0.000028
# 5       0.0000  0.029872    5.37688           0.0    0.000036
# 6       0.0000  0.032558    5.86044           0.0    0.000045
# 7       0.0000  0.035306    6.35514           0.0    0.000056
# 8       0.0000  0.038118    6.86120           0.0    0.000069
# 9       0.0000  0.040994    7.37886           0.0    0.000083
# 10      0.0000  0.043935    7.90835           0.0    0.000099
# 11      0.0000  0.046944    8.44989           0.0    0.000118
# 12      0.0000  0.050021    9.00373           0.0    0.000138
# 13      0.0000  0.053167    9.57010           0.0    0.000160
# ...

# %%
c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re180_Pr0_2.csv',header=True, index=False)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re180_Pr0_7.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)
# Out:
# (81620, 55)

# %%
c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(385):
    for j in range(106):
        c.loc[j+106*i] = (Data.loc[j+2*106*i] + Data.loc[211-j+2*106*i])/2
        c['Y'][j+106*i] = Data.loc[j+2*106*i][1]
c
# Out:
#              X         Y     y_plus  wedge_height  Nu_t_lsq_n  \
# 0       0.0000  0.017326    3.11864           0.0    0.000008
# 1       0.0000  0.019721    3.54973           0.0    0.000011
# 2       0.0000  0.022172    3.99089           0.0    0.000016
# 3       0.0000  0.024680    4.44233           0.0    0.000021
# 4       0.0000  0.027246    4.90425           0.0    0.000028
# 5       0.0000  0.029872    5.37688           0.0    0.000036
# 6       0.0000  0.032558    5.86044           0.0    0.000045
# 7       0.0000  0.035306    6.35514           0.0    0.000056
# 8       0.0000  0.038118    6.86120           0.0    0.000069
# 9       0.0000  0.040994    7.37886           0.0    0.000083
# 10      0.0000  0.043935    7.90835           0.0    0.000099
# 11      0.0000  0.046944    8.44989           0.0    0.000118
# 12      0.0000  0.050021    9.00373           0.0    0.000138
# 13      0.0000  0.053167    9.57010           0.0    0.000160
# ...

# %%
c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re180_Pr0_7.csv',header=True, index=False)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re180_Pr2.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)

c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(385):
    for j in range(106):
        c.loc[j+106*i] = (Data.loc[j+2*106*i] + Data.loc[211-j+2*106*i])/2
        c['Y'][j+106*i] = Data.loc[j+2*106*i][1]
print(c.shape)

c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re180_Pr2.csv',header=True, index=False)
# Out:
# (81620, 54)
# (40810, 54)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re400_Pr0_2.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)

c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(401):
    for j in range(219):
        c.loc[j+219*i] = (Data.loc[j+2*219*i] + Data.loc[437-j+2*219*i])/2
        c['Y'][j+219*i] = Data.loc[j+2*219*i][1]
        
print(c.shape)

c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re400_Pr0_2.csv',header=True, index=False)
# Out:
# (175638, 54)
# (87819, 54)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re400_Pr0_7.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)

c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(401):
    for j in range(219):
        c.loc[j+219*i] = (Data.loc[j+2*219*i] + Data.loc[437-j+2*219*i])/2
        c['Y'][j+219*i] = Data.loc[j+2*219*i][1]
        
print(c.shape)

c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re400_Pr0_7.csv',header=True, index=False)
# Out:
# (175638, 55)
# (87819, 55)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re400_Pr2.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)

c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(401):
    for j in range(219):
        c.loc[j+219*i] = (Data.loc[j+2*219*i] + Data.loc[437-j+2*219*i])/2
        c['Y'][j+219*i] = Data.loc[j+2*219*i][1]
        
print(c.shape)

c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re400_Pr2.csv',header=True, index=False)
# Out:
# (175638, 55)
# (87819, 55)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re590_Pr0_2.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)

c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(401):
    for j in range(221):
        c.loc[j+221*i] = (Data.loc[j+2*221*i] + Data.loc[441-j+2*221*i])/2
        c['Y'][j+221*i] = Data.loc[j+2*221*i][1]
        
print(c.shape)

c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re590_Pr0_2.csv',header=True, index=False)
# Out:
# (177242, 54)
# (88621, 54)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re590_Pr0_7.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)

c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(401):
    for j in range(221):
        c.loc[j+221*i] = (Data.loc[j+2*221*i] + Data.loc[441-j+2*221*i])/2
        c['Y'][j+221*i] = Data.loc[j+2*221*i][1]
        
print(c.shape)

c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re590_Pr0_7.csv',header=True, index=False)
# Out:
# (177242, 55)
# (88621, 55)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_Re590_Pr2.csv')
# Data = Data.drop_duplicates(['X','Y'], keep='last')
Data = Data.sort_values(by=['X','Y'])
Data = Data.reindex([i for i in range(len(Data))])
print(Data.shape)

c = pd.DataFrame(columns=Data.columns)
# c = Data.iloc[0]
for i in range(401):
    for j in range(221):
        c.loc[j+221*i] = (Data.loc[j+2*221*i] + Data.loc[441-j+2*221*i])/2
        c['Y'][j+221*i] = Data.loc[j+2*221*i][1]
        
print(c.shape)

c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re590_Pr2.csv',header=True, index=False)
# Out:
# (177242, 55)
# (88621, 55)

# %%
Data['Re']
# Out:
# 0         590.0
# 1         590.0
# 2         590.0
# 3         590.0
# 4         590.0
# 5         590.0
# 6         590.0
# 7         590.0
# 8         590.0
# 9         590.0
# 10        590.0
# 11        590.0
# 12        590.0
# 13        590.0
# 14        590.0
# 15        590.0
# 16        590.0
# 17        590.0
# 18        590.0
# 19        590.0
# 20        590.0
# 21        590.0
# 22        590.0
# 23        590.0
# 24        590.0
# 25        590.0
# 26        590.0
# 27        590.0
# 28        590.0
# 29        590.0
#           ...
# 143072    180.0
# 143073    180.0
# 143074    180.0
# 143075    180.0
# 143076    180.0
# 143077    180.0
# 143078    180.0
# 143079    180.0
# 143080    180.0
# 143081    180.0
# 143082    180.0
# 143083    180.0
# 143084    180.0
# 143085    180.0
# 143086    180.0
# 143087    180.0
# 143088    180.0
# 143089    180.0
# 143090    180.0
# 143091    180.0
# 143092    180.0
# 143093    180.0
# 143094    180.0
# 143095    180.0
# ...

# %%
import pandas as pd
Data1 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re180_Pr0_2.csv')
Data2 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re180_Pr0_7.csv')
Data3 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re180_Pr2.csv')
Data4 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re400_Pr0_2.csv')
Data5 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re400_Pr0_7.csv')
Data6 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re400_Pr2.csv')
Data7 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re590_Pr0_2.csv')
Data8 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re590_Pr0_7.csv')
Data9 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_Re590_Pr2.csv')

# %%
Data1.shape
# Out:
# (40810, 54)

# %%
data1 = pd.DataFrame(Data1, columns=Data1.columns)
data2 = pd.DataFrame(Data2, columns=Data1.columns)
data3 = pd.DataFrame(Data3, columns=Data1.columns)
data4 = pd.DataFrame(Data4, columns=Data1.columns)
data5 = pd.DataFrame(Data5, columns=Data1.columns)
data6 = pd.DataFrame(Data6, columns=Data1.columns)
data7 = pd.DataFrame(Data7, columns=Data1.columns)
data8 = pd.DataFrame(Data8, columns=Data1.columns)
data9 = pd.DataFrame(Data9, columns=Data1.columns)

# %%
full_data = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9])
full_data.head()
# Out:
#      X         Y   y_plus  wedge_height  Nu_t_lsq_n  PHI-Alpha_t_lsq_n  \
# 0  0.0  0.017326  3.11864           0.0    0.000008           0.000007
# 1  0.0  0.019721  3.54973           0.0    0.000011           0.000011
# 2  0.0  0.022172  3.99089           0.0    0.000016           0.000015
# 3  0.0  0.024680  4.44233           0.0    0.000021           0.000020
# 4  0.0  0.027246  4.90425           0.0    0.000028           0.000027
#
#       tke_n         dk/dx     dk/dy  dk_dx_i_abs  ...      Vi_AVG_n  Wi_AVG_n  \
# 0  0.002139  5.910000e-08  0.003495     0.220769  ...  9.900000e-11 -0.000015
# 1  0.002695  6.970000e-08  0.003432     0.237789  ...  1.010000e-10 -0.000016
# 2  0.003301  7.830000e-08  0.003207     0.250583  ...  1.040000e-10 -0.000018
# 3  0.003948  8.380000e-08  0.002826     0.258777  ...  1.100000e-10 -0.000018
# 4  0.004624  8.545000e-08  0.002312     0.262215  ...  1.220000e-10 -0.000019
#
# ...

# %%
a = full_data.sort_values(by=['Y'])
a
# Out:
#                X         Y     y_plus  wedge_height  Nu_t_lsq_n  \
# 36686   2.607520  0.006114    3.60708           0.0    0.000005
# 3536    0.251327  0.006114    3.60708           0.0    0.000005
# 50830   3.612830  0.006114    3.60708           0.0    0.000005
# 35802   2.544690  0.006114    3.60708           0.0    0.000005
# 72488   5.152210  0.006114    3.60708           0.0    0.000005
# 67405   4.790930  0.006114    3.60708           0.0    0.000005
# 62764   4.461060  0.006114    3.60708           0.0    0.000005
# 12376   0.879646  0.006114    3.60708           0.0    0.000005
# 32929   2.340490  0.006114    3.60708           0.0    0.000005
# 77792   5.529200  0.006114    3.60708           0.0    0.000005
# 12155   0.863938  0.006114    3.60708           0.0    0.000005
# 33150   2.356190  0.006114    3.60708           0.0    0.000005
# 51051   3.628540  0.006114    3.60708           0.0    0.000005
# 11934   0.848230  0.006114    3.60708           0.0    0.000005
# ...

# %%
full_data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_all_Re.csv',header=True,index=False)
