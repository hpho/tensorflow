# %%
import pandas as pd

# %%
#데이터 불러오기
data=pd.read_csv(r'D:\Desktop\pr_t_data\case1.csv')

#X,Y 오름차순 정렬
data.sort_values(by=['X','Y'],inplace=True)

#데이터프레임에 단일값을 가지는 컬럼 추가
data["Pr"]=0.7
data["Re_tau"]=0.18

#데이터 필터링 과정 Y값이 0.8<Y<1.2 인부분 제외, y_plus가 >3 인 데이터만 추출
data=data.drop(data[(data.Y<1.2)&(data.Y>0.8)].index)
data=data[data.y_plus>3]

data.shape

#full parameter 

full_parameter_data=data[['Pr','Re_tau','Nu_t_lsq','tke','tke_diss','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss','tfe_diff',
             'tfe_conv_tur','tfe_prod','dk/dx','dk/dy','dk/dx_i',"dT'T'/dx","dT'T'/dy",
             "dT'T'/dx_i","dp_dx","dp_dy","dp_dx_i","dT/dx","dT/dy","dT/dx_i","S_11","S_12",
             "S_22","S_ij_abs","u_du/dx+v_dv/dx","Mean_tke_mol_diff","Mean_tke_pre_diff",
             "Mean_tke_diss","Mean_tfe_mol_diff","Mean_tfe_diss","Pr_t_ke","Pr_t_new",
             "X","Y"]]


full_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함
full_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case1_Total_parameters_36.csv', header=True, index=False)

#modeling parameter Pr_t_new 랑 Pr_t랑 어떤거?

modeling_parameter_data=data[['Pr','Re_tau',"Nu_t_lsq",'tke','tke_diss','dp_dx','dp_dy','dp_dx_i','dT/dx','dT/dy',
                              'dT/dx_i','S_11','S_12','S_22','S_ij_abs','dk/dx','dk/dy','dk/dx_i',
                              'u_du/dx+v_dv/dx','Mean_tke_mol_diff','Mean_tke_pre_diff','Mean_tke_diss',
                              'Mean_tfe_mol_diff','Mean_tfe_diss','Pr_t_ke','Pr_t_new','X','Y']]



modeling_parameter_data.shape


modeling_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case1_Modeling_parameters_24.csv', header=True, index=False)

#fuctuation parameter

fluctuation_parameter_data=data[['Pr','Re_tau','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss',
                                 'tfe_diff','tfe_conv_tur','tfe_prod',"dT'T'/dx","dT'T'/dy",
                                 "dT'T'/dx_i",'Pr_t_ke','Pr_t_new','X','Y']]



fluctuation_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함 
fluctuation_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case1_Fluctuation_parameters_14.csv', header=True, index=False)

# %%
#데이터 불러오기
data=pd.read_csv(r'D:\Desktop\pr_t_data\case2.csv')

#X,Y 오름차순 정렬
data.sort_values(by=['X','Y'],inplace=True)

#데이터프레임에 단일값을 가지는 컬럼 추가
data["Pr"]=0.7
data["Re_tau"]=0.4

#데이터 필터링 과정 Y값이 0.8<Y<1.2 인부분 제외, y_plus가 >3 인 데이터만 추출
data=data.drop(data[(data.Y<1.2)&(data.Y>0.8)].index)
data=data[data.y_plus>3]

data.shape

#full parameter 

full_parameter_data=data[['Pr','Re_tau','Nu_t_lsq','tke','tke_diss','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss','tfe_diff',
             'tfe_conv_tur','tfe_prod','dk/dx','dk/dy','dk/dx_i',"dT'T'/dx","dT'T'/dy",
             "dT'T'/dx_i","dp_dx","dp_dy","dp_dx_i","dT/dx","dT/dy","dT/dx_i","S_11","S_12",
             "S_22","S_ij_abs","u_du/dx+v_dv/dx","Mean_tke_mol_diff","Mean_tke_pre_diff",
             "Mean_tke_diss","Mean_tfe_mol_diff","Mean_tfe_diss","Pr_t_ke","Pr_t_new",
             "X","Y"]]


full_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함
full_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case2_Total_parameters_36.csv', header=True, index=False)

#modeling parameter Pr_t_new 랑 Pr_t랑 어떤거?

modeling_parameter_data=data[['Pr','Re_tau',"Nu_t_lsq",'tke','tke_diss','dp_dx','dp_dy','dp_dx_i','dT/dx','dT/dy',
                              'dT/dx_i','S_11','S_12','S_22','S_ij_abs','dk/dx','dk/dy','dk/dx_i',
                              'u_du/dx+v_dv/dx','Mean_tke_mol_diff','Mean_tke_pre_diff','Mean_tke_diss',
                              'Mean_tfe_mol_diff','Mean_tfe_diss','Pr_t_ke','Pr_t_new','X','Y']]



modeling_parameter_data.shape


modeling_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case2_Modeling_parameters_24.csv', header=True, index=False)

#fuctuation parameter

fluctuation_parameter_data=data[['Pr','Re_tau','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss',
                                 'tfe_diff','tfe_conv_tur','tfe_prod',"dT'T'/dx","dT'T'/dy",
                                 "dT'T'/dx_i",'Pr_t_ke','Pr_t_new','X','Y']]



fluctuation_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함 
fluctuation_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case2_Fluctuation_parameters_14.csv', header=True, index=False)

# %%
#데이터 불러오기
data=pd.read_csv(r'D:\Desktop\pr_t_data\case5.csv')

#X,Y 오름차순 정렬
data.sort_values(by=['X','Y'],inplace=True)

#데이터프레임에 단일값을 가지는 컬럼 추가
data["Pr"]=0.7
data["Re_tau"]=0.18

#데이터 필터링 과정 Y값이 0.8<Y<1.2 인부분 제외, y_plus가 >3 인 데이터만 추출
data=data.drop(data[(data.Y<1.2)&(data.Y>0.8)].index)
data=data[data.y_plus>3]

data.shape

#full parameter 

full_parameter_data=data[['Pr','Re_tau','Nu_t_lsq','tke','tke_diss','tke_diff','tke_pre','tke_conv_tur','tke_prod','PHI_2-tfe','PHI_2-tfe_diss','PHI_2-tfe_diff',
             'PHI_2-tfe_conv_tur','PHI_2-tfe_prod','dk/dx','dk/dy','dk/dx_i',"dT'T'/dx","dT'T'/dy",
             "dT'T'/dx_i","dp_dx","dp_dy","dp_dx_i","dT/dx","dT/dy","dT/dx_i","S_11","S_12",
             "S_22","S_ij_abs","u_du/dx+v_dv/dx","Mean_tke_mol_diff","Mean_tke_pre_diff",
             "Mean_tke_diss","Mean_tfe_mol_diff","Mean_tfe_diss","Pr_t_ke","Pr_t_new",
             "X","Y"]]


full_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함
full_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case5_Total_parameters_36.csv', header=True, index=False)

#modeling parameter Pr_t_new 랑 Pr_t랑 어떤거?

modeling_parameter_data=data[['Pr','Re_tau',"Nu_t_lsq",'tke','tke_diss','dp_dx','dp_dy','dp_dx_i','dT/dx','dT/dy',
                              'dT/dx_i','S_11','S_12','S_22','S_ij_abs','dk/dx','dk/dy','dk/dx_i',
                              'u_du/dx+v_dv/dx','Mean_tke_mol_diff','Mean_tke_pre_diff','Mean_tke_diss',
                              'Mean_tfe_mol_diff','Mean_tfe_diss','Pr_t_ke','Pr_t_new','X','Y']]



modeling_parameter_data.shape


modeling_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case5_Modeling_parameters_24.csv', header=True, index=False)

#fuctuation parameter

fluctuation_parameter_data=data[['Pr','Re_tau','tke_diff','tke_pre','tke_conv_tur','tke_prod','PHI_2-tfe','PHI_2-tfe_diss',
                                 'PHI_2-tfe_diff','PHI_2-tfe_conv_tur','PHI_2-tfe_prod',"dT'T'/dx","dT'T'/dy",
                                 "dT'T'/dx_i",'Pr_t_ke','Pr_t_new','X','Y']]



fluctuation_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함 
fluctuation_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case5_Fluctuation_parameters_14.csv', header=True, index=False)

# %%
#데이터 불러오기
data=pd.read_csv(r'D:\Desktop\pr_t_data\case6.csv')

#X,Y 오름차순 정렬
data.sort_values(by=['X','Y'],inplace=True)

#데이터프레임에 단일값을 가지는 컬럼 추가
data["Pr"]=0.7
data["Re_tau"]=0.4

#데이터 필터링 과정 Y값이 0.8<Y<1.2 인부분 제외, y_plus가 >3 인 데이터만 추출
data=data.drop(data[(data.Y<1.2)&(data.Y>0.8)].index)
data=data[data.y_plus>3]

data.shape

#full parameter 

full_parameter_data=data[['Pr','Re_tau','Nu_t_lsq','tke','tke_diss','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss','tfe_diff',
             'tfe_conv_tur','tfe_prod','dk/dx','dk/dy','dk/dx_i',"dT'T'/dx","dT'T'/dy",
             "dT'T'/dx_i","dp_dx","dp_dy","dp_dx_i","dT/dx","dT/dy","dT/dx_i","S_11","S_12",
             "S_22","S_ij_abs","u_du/dx+v_dv/dx","Mean_tke_mol_diff","Mean_tke_pre_diff",
             "Mean_tke_diss","Mean_tfe_mol_diff","Mean_tfe_diss","Pr_t_ke","Pr_t_new",
             "X","Y"]]


full_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함
full_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case6_Total_parameters_36.csv', header=True, index=False)

#modeling parameter Pr_t_new 랑 Pr_t랑 어떤거?

modeling_parameter_data=data[['Pr','Re_tau',"Nu_t_lsq",'tke','tke_diss','dp_dx','dp_dy','dp_dx_i','dT/dx','dT/dy',
                              'dT/dx_i','S_11','S_12','S_22','S_ij_abs','dk/dx','dk/dy','dk/dx_i',
                              'u_du/dx+v_dv/dx','Mean_tke_mol_diff','Mean_tke_pre_diff','Mean_tke_diss',
                              'Mean_tfe_mol_diff','Mean_tfe_diss','Pr_t_ke','Pr_t_new','X','Y']]



modeling_parameter_data.shape


modeling_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case6_Modeling_parameters_24.csv', header=True, index=False)

#fuctuation parameter

fluctuation_parameter_data=data[['Pr','Re_tau','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss',
                                 'tfe_diff','tfe_conv_tur','tfe_prod',"dT'T'/dx","dT'T'/dy",
                                 "dT'T'/dx_i",'Pr_t_ke','Pr_t_new','X','Y']]



fluctuation_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함 
fluctuation_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case6_Fluctuation_parameters_14.csv', header=True, index=False)

# %%
#데이터 불러오기
data=pd.read_csv(r'D:\Desktop\pr_t_data\case9.csv')

#X,Y 오름차순 정렬
data.sort_values(by=['X','Y'],inplace=True)

#데이터프레임에 단일값을 가지는 컬럼 추가
data["Pr"]=0.7
data["Re_tau"]=0.18

#데이터 필터링 과정 Y값이 0.8<Y<1.2 인부분 제외, y_plus가 >3 인 데이터만 추출
data=data.drop(data[(data.Y<1.2)&(data.Y>0.8)].index)
data=data[data.y_plus>3]

data.shape

#full parameter 

full_parameter_data=data[['Pr','Re_tau','Nu_t_lsq','tke','tke_diss','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss','tfe_diff',
             'tfe_conv_tur','tfe_prod','dk/dx','dk/dy','dk/dx_i',"dT'T'/dx","dT'T'/dy",
             "dT'T'/dx_i","dp_dx","dp_dy","dp_dx_i","dT/dx","dT/dy","dT/dx_i","S_11","S_12",
             "S_22","S_ij_abs","u_du/dx+v_dv/dx","Mean_tke_mol_diff","Mean_tke_pre_diff",
             "Mean_tke_diss","Mean_tfe_mol_diff","Mean_tfe_diss","Pr_t_ke","Pr_t_new",
             "X","Y"]]


full_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함
full_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case9_Total_parameters_36.csv', header=True, index=False)

#modeling parameter Pr_t_new 랑 Pr_t랑 어떤거?

modeling_parameter_data=data[['Pr','Re_tau',"Nu_t_lsq",'tke','tke_diss','dp_dx','dp_dy','dp_dx_i','dT/dx','dT/dy',
                              'dT/dx_i','S_11','S_12','S_22','S_ij_abs','dk/dx','dk/dy','dk/dx_i',
                              'u_du/dx+v_dv/dx','Mean_tke_mol_diff','Mean_tke_pre_diff','Mean_tke_diss',
                              'Mean_tfe_mol_diff','Mean_tfe_diss','Pr_t_ke','Pr_t_new','X','Y']]



modeling_parameter_data.shape


modeling_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case9_Modeling_parameters_24.csv', header=True, index=False)

#fuctuation parameter

fluctuation_parameter_data=data[['Pr','Re_tau','tke_diff','tke_pre','tke_conv_tur','tke_prod','tfe','tfe_diss',
                                 'tfe_diff','tfe_conv_tur','tfe_prod',"dT'T'/dx","dT'T'/dy",
                                 "dT'T'/dx_i",'Pr_t_ke','Pr_t_new','X','Y']]



fluctuation_parameter_data.shape

# header : 변수 이름 포함   index 행 번호 포함 
fluctuation_parameter_data.to_csv(r'D:\Desktop\pr_t_data\case9_Fluctuation_parameters_14.csv', header=True, index=False)
