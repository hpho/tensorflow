# %%
#폴더 만들기
import os
Dir = "D:\Desktop\\190411"

for i in range(5):
    Dirname = "k_fold10num_train1#%d" %(i+1)
    if not os.path.isdir(Dir+"\\"+Dirname):
        os.mkdir(Dir+"\\"+Dirname)

# %%
#파일명 변경
import os
Dir = "D:\Desktop\\190305\\csvfile\\new\\새 폴더 (3)\\"

os.rename(Dir+'uniform_wedge_Re180_Pr0_2.csv',Dir+'case1_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re180_Pr0_7.csv',Dir+'case2_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re180_Pr2_0.csv',Dir+'case3_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re400_Pr0_2.csv',Dir+'case4_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re400_Pr0_7.csv',Dir+'case5_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re400_Pr2_0.csv',Dir+'case6_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re590_Pr0_2.csv',Dir+'case7_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re590_Pr0_7.csv',Dir+'case8_total_uniform_wedge.csv')
os.rename(Dir+'uniform_wedge_Re590_Pr2_0.csv',Dir+'case9_total_uniform_wedge.csv')

# %%
os.rename(Dir+'uniform_channel_Re180_Pr0_2.csv',Dir+'case1_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re180_Pr0_7.csv',Dir+'case2_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re180_Pr2.csv',Dir+'case3_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re400_Pr0_2.csv',Dir+'case4_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re400_Pr0_7.csv',Dir+'case5_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re400_Pr2.csv',Dir+'case6_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re590_Pr0_2.csv',Dir+'case7_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re590_Pr0_7.csv',Dir+'case8_total_uniform_channel.csv')
os.rename(Dir+'uniform_channel_Re590_Pr2.csv',Dir+'case9_total_uniform_channel.csv')

# %%
import pandas as pd
Data = pd.read_csv(r'D:/Desktop/190305/csvfile/new/새 폴더 (3)/uniform_wedge_Re180_Pr0_2.csv')
Data.shape
# Out:
# (179927, 55)

# %%
Data.columns
# Out:
# Index(['X', 'Y', 'y_plus', 'wedge_height', 'Nu_t_lsq', 'Alpha_t', 'tke',
#        'dk/dx', 'dk/dy', 'dk/dx_i_abs', 'tke_diss', 'TV_prod(al_t_1)',
#        'tke_prod(nu_t_1_new)', 'Rp', 'Rd', 'TV', 'tke_sdm', 'tke_conv_turb',
#        'tke_pre', 'tke_diff', 'TV_sdm', 'TV_conv_turb', 'TV_diff', 'TV_diss',
#        'dp/dx', 'dp/dy', 'dp/dx_i_abs', 'u_du/dx+v_dv/dx', 'MKE_pre',
#        'MKE_diss', 'MKE_visc_diff', 'MTV_diss', 'MTV_mol_diff', 'dT/dx',
#        'dT/dy', 'dT/dx_i_abs', 'S_ij_abs', 'S_11', 'S_12(=S_21)', 'S_22', 'Re',
#        'Pr', 'Pr_t', 'dTvar/dx_i_abs', 'Rp/Rd', 'U-AVG-X', 'U-AVG-Y',
#        'U-AVG-Z', 'du/dx', 'du/dy', 'dv/dx', 'dv/dy', 'P_AVG', '1/Pr',
#        'local volume'],
#       dtype='object')

# %%
del Data['X'], Data['Y']

# %%
Data
# Out:
#           y_plus  wedge_height  Nu_t_lsq   Alpha_t       tke     dk/dx  \
# 0        3.18154           0.1  0.000024  0.000024  0.003241  0.002604
# 1        4.03351           0.1  0.000045  0.000042  0.004774  0.002813
# 2        4.75275           0.1  0.000073  0.000066  0.006387  0.002863
# 3        5.50149           0.1  0.000109  0.000096  0.007968  0.002810
# 4        6.27630           0.1  0.000152  0.000132  0.009436  0.002665
# 5        7.06350           0.1  0.000203  0.000174  0.010739  0.002446
# 6        7.84485           0.1  0.000262  0.000223  0.011860  0.002186
# 7        8.52601           0.1  0.000327  0.000276  0.012798  0.001921
# 8        9.59521           0.1  0.000401  0.000336  0.013553  0.001686
# 9       10.19460           0.1  0.000480  0.000400  0.014149  0.001371
# 10      11.06860           0.1  0.000566  0.000469  0.014610  0.001254
# 11      11.68560           0.1  0.000659  0.000542  0.014940  0.001107
# ...
