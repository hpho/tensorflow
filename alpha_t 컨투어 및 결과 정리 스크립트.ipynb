# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

Data = pd.read_csv(r'D:\Desktop\190729\channel_y_plus\nogird_orig_csv_0.csv')
Data.head()

data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_all_Re.csv')

aa = abs(Data['Pr_t_test'] - Data['Pr_t_model'])

a = pd.DataFrame()
# a['nu_t'] = data['Nu_t_lsq_n'][Data['index']]
# a['index'] = [i for i in range(len(Data['index']))]
# a['X'] = data['X'][Data['index']]
# a['Y'] = data['Y'][Data['index']]
# a['pr_t_error'] = aa
# a['alpha_error'] = real_alpha-model_alpha
a['X'] = data.iloc[Data['index']].X
a['Y'] = data.iloc[Data['index']].Y
a['y_plus'] = data.iloc[Data['index']].y_plus
a['Re'] = data.iloc[Data['index']].Re
a['Pr'] = data.iloc[Data['index']].Pr
a['Pr_t'] = data.iloc[Data['index']]['PHI-Pr_t_new']
a = a.reset_index(drop=True)
a['Pr_t_error'] = aa
b = pd.DataFrame()
b['nu_t'] = data['Nu_t_lsq_n'][Data['index']]
b = b.reset_index(drop=True)
real_alpha = b['nu_t']/Data['Pr_t_test']
model_alpha = b['nu_t']/Data['Pr_t_model']
a['alpha_t_error'] = abs(real_alpha - model_alpha)
a
# Out:
#                 X         Y     y_plus     Re   Pr      Pr_t  Pr_t_error  \
# 0        4.979420  0.145309   85.73230  590.0  2.0  0.916694    0.001003
# 1        0.785398  0.009329    3.73178  400.0  0.7  1.011525    0.000082
# 2        4.068360  0.043885   25.89220  590.0  0.7  0.987926    0.000849
# 3        3.567020  0.431540   77.67720  180.0  0.7  0.967290    0.001036
# 4        1.272350  0.057966   23.18630  400.0  0.2  1.068485    0.000369
# 5        3.408630  0.150498   60.19910  400.0  0.2  1.090685    0.000911
# 6        0.047124  0.531689  313.69700  590.0  2.0  0.824806    0.000543
# 7        3.015930  0.426490  251.62900  590.0  0.2  0.900335    0.000412
# 8        1.994910  0.049968   19.98740  400.0  0.7  0.979202    0.000681
# 9        2.686060  0.655256  262.10200  400.0  0.2  0.880045    0.000857
# 10       1.649340  0.066419   26.56760  400.0  0.7  0.987892    0.000132
# 11       0.109956  0.049968   19.98740  400.0  0.2  1.053215    0.000433
# ...

# %%
a.to_csv(r'D:\Desktop\190729\channel_y_plus\nogrid_orig_channel.csv',header=True, index=False)

# %%
c = abs(real_alpha - model_alpha)/real_alpha*100
max(c)
# Out:
# 5.063604506654842

# %%
a.mean()
# Out:
# X                  3.733087
# Y                  0.294768
# y_plus           127.705862
# Re               435.954305
# Pr                 0.967808
# Pr_t               0.942464
# Pr_t_error         0.000751
# alpha_t_error      0.000003
# dtype: float64

# %%
a_real = Data['nu_t_test']/Data['Pr_t_test']
a_model = Data['nu_t_test']/Data['Pr_t_model']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\user\anaconda\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nu_t_test'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-ddda5aba7e4f> in <module>
# ...

# %%
plt.scatter(Data['Pr_t_test'],Data['Pr_t_model'],s=0.5)
plt.grid(True)

# %%
data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\orig_channel_all_Re.csv')

# %%
data.head()
# Out:
#      X         Y   y_plus  wedge_height  Nu_t_lsq_n  PHI-Alpha_t_lsq_n  \
# 0  0.0  0.017326  3.11864             0    0.000008           0.000008
# 1  0.0  0.019721  3.54973             0    0.000011           0.000011
# 2  0.0  0.022172  3.99089             0    0.000016           0.000015
# 3  0.0  0.024680  4.44233             0    0.000022           0.000021
# 4  0.0  0.027246  4.90425             0    0.000029           0.000027
#
#       tke_n         dk/dx     dk/dy  dk_dx_i_abs  ...         du/dx    du/dy  \
# 0  0.002179  6.140000e-08  0.224264     0.224264  ...  3.050000e-07  9.41645
# 1  0.002743  7.220000e-08  0.241222     0.241222  ...  3.400000e-07  9.28667
# 2  0.003357  8.080000e-08  0.253790     0.253790  ...  3.630000e-07  9.13142
# 3  0.004012  8.600000e-08  0.261604     0.261604  ...  3.730000e-07  8.94992
# 4  0.004695  8.720000e-08  0.264527     0.264527  ...  3.670000e-07  8.74224
#
# ...

# %%
# pd.set_option('display.float_format', '{:.2e}'.format)

aa = abs(Data['Pr_t_test'] - Data['Pr_t_model'])
aa
# Out:
# 0         7.758653e-05
# 1         1.349464e-03
# 2         1.896242e-03
# 3         1.088422e-03
# 4         4.915582e-05
# 5         1.455190e-03
# 6         1.487002e-03
# 7         1.086699e-03
# 8         1.810248e-03
# 9         2.011635e-04
# 10        1.435933e-04
# 11        4.716282e-04
# 12        9.573655e-07
# 13        9.439852e-04
# 14        1.137987e-03
# 15        5.162748e-04
# 16        1.546771e-03
# 17        1.031434e-03
# 18        8.005567e-04
# 19        9.607627e-04
# 20        1.711060e-03
# 21        7.991935e-05
# 22        7.684818e-04
# 23        3.451968e-05
# 24        1.088422e-03
# 25        3.373178e-04
# 26        5.462861e-04
# 27        1.109689e-04
# 28        2.011706e-04
# 29        2.725086e-04
#               ...
# 430125    1.771382e-03
# 430126    3.356227e-03
# 430127    3.165555e-04
# 430128    2.940780e-04
# 430129    2.258669e-04
# 430130    7.267335e-04
# 430131    1.100199e-04
# 430132    2.543585e-03
# 430133    9.580147e-04
# ...

# %%
data.columns
# Out:
# Index(['X', 'Y', 'y_plus', 'wedge_height', 'Nu_t_lsq_n', 'PHI-Alpha_t_lsq_n',
#        'tke_n', 'dk/dx', 'dk/dy', 'dk_dx_i_abs', 'tke_diss_n',
#        'PHI-tfe_prod_n', 'tke_prod_n', 'PHI-Rp', 'PHI-Rd', 'PHI-TV',
#        'tke_sdm_n', 'tke_conv_tur_n', 'tke_pre_n', 'tke_diff_n',
#        'PHI-tfe_sdm_n', 'PHI-tfe_conv_tur_n', 'PHI-tfe_diff_n',
#        'PHI-tfe_diss_n', 'dp_dx', 'dp_dy', 'dp_dx_i_abs', 'u_du/dx+v_dv/dx',
#        'Mean_tke_pre_diff', 'Mean_tke_diss', 'Mean_tke_visc_diff',
#        'Mean_tfe_diss', 'Mean_tfe_mol_diff', 'dT/dx', 'dT/dy', 'dT/dx_i_abs',
#        'S_ij_abs', 'S_11', 'S_12(=S_21)', 'S_22', 'Re', 'Pr', 'dTvar/dx_i_abs',
#        'Ui_AVG_n', 'Vi_AVG_n', 'Wi_AVG_n', 'du/dx', 'du/dy', 'dv/dx', 'dv/dy',
#        'P_AVG_n', '1/Pr', 'local_volume', 'Pr_t'],
#       dtype='object')

# %%
a = pd.DataFrame()
# a['nu_t'] = data['Nu_t_lsq_n'][Data['index']]
# a['index'] = [i for i in range(len(Data['index']))]
# a['X'] = data['X'][Data['index']]
# a['Y'] = data['Y'][Data['index']]
# a['pr_t_error'] = aa
# a['alpha_error'] = real_alpha-model_alpha
a['X'] = data.iloc[Data['index']].X
a['Y'] = data.iloc[Data['index']].Y
a['y_plus'] = data.iloc[Data['index']].y_plus
a['Re'] = data.iloc[Data['index']].Re
a['Pr'] = data.iloc[Data['index']].Pr
a['Pr_t'] = data.iloc[Data['index']].Pr_t
a = a.reset_index(drop=True)
a['Pr_t_error'] = aa
a['alpha_t_error'] = abs(real_alpha - model_alpha)
a
# a.to_excel(r'D:\Desktop\190729\목요일미팅자료\orig_channel.xlsx',header=True, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\user\anaconda\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-48fe36d3b27e> in <module>
# ...

# %%
a = a.sort_values(['alpha_t_error'], ascending=[False])
a.head(200)
# Out:
#                 X         Y   y_plus   Re   Pr  Pr_t_error  alpha_t_error
# 345219   6.094690  1.411030  235.590  400  0.7    0.000004   1.454314e+06
# 344758   1.790710  1.411030  235.590  400  0.7    0.000004   8.871044e+05
# 219608   6.110400  1.411030  235.590  400  0.7    0.000004   5.212411e+05
# 84618    0.032725  0.132861   23.915  180  2.0    0.000001   3.218295e+05
# 57273   11.977300  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# 387041   9.948380  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# 376929   9.097530  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# 109561   2.388920  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# 294185   6.872230  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# 88726    5.105090  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# 207432   1.341720  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# 26383    5.923210  0.132861   23.915  180  2.0    0.000001   3.110857e+05
# ...

# %%
b = pd.DataFrame()
b['nu_t'] = data['Nu_t_lsq_n'][Data['index']]
b = b.reset_index(drop=True)
real_alpha = b['nu_t']/Data['Pr_t_test']
model_alpha = b['nu_t']/Data['Pr_t_model']
c = real_alpha - model_alpha
max(c)
# Out:
# 4.801781870391805e-05

# %%
plt.scatter(real_alpha,model_alpha,s=0.1)
plt.grid(True)

# %%
# import numpy as np
# XX, YY = np.meshgrid(a['X'],a['Y'])
# plt.contourf(XX,YY,Data['Pr_t_test']-Data['Pr_t_model'])
plt.plot(a['X'],a['Y'],Data['Pr_t_test']-Data['Pr_t_model'])

# %%
rela_error =  abs(real_alpha - model_alpha)/real_alpha*100

# %%
import numpy as np
mean_error = np.mean(rela_error)
mean_error
# Out:
# 0.1171429590215645

# %%
max_error = np.max(rela_error)
max_error
# Out:
# 5.5971112665241565

# %%
import pandas as pd

Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\orig_channel_all_Re.csv')

max(Data['Y'])
# Out:
# 1.99389

# %%
max(Data['X'])
# Out:
# 12.5664

# %%
a = []
for i in range(len(Data['Y'])):
    if Data['Y'][i] < 1:
        a.append(Data['Y'][i])
    if Data['Y'][i] > 1:
        a.append(2 - Data['Y'][i])
a
# Out:
# [0.0173258,
#  0.0197207,
#  0.0221716,
#  0.0246796,
#  0.0272459,
#  0.0298716,
#  0.032558,
#  0.035306300000000006,
#  0.03811780000000002,
#  0.040993699999999994,
#  0.043935300000000004,
#  0.046943900000000004,
#  0.0500207,
#  0.053167200000000005,
#  0.056384699999999996,
#  0.0596744,
#  0.0630378,
#  0.0664763,
#  0.0699911,
#  0.0735838,
#  0.0772558,
#  0.0810084,
#  0.08484320000000001,
#  0.08876139999999999,
#  0.09276469999999999,
#  0.0968544,
#  0.10103200000000001,
#  0.105299,
#  0.10965699999999999,
#  0.114107,
#  0.11865099999999999,
#  0.12329100000000001,
#  0.128027,
#  0.13286099999999998,
#  0.137795,
#  0.14283099999999999,
#  0.14796900000000002,
#  0.15321099999999999,
#  0.158558,
#  0.16401300000000002,
#  0.169576,
#  0.175249,
#  0.181034,
#  0.18692999999999999,
#  0.192941,
#  0.199068,
#  0.20531,
#  0.211671,
#  0.218151,
#  0.224752,
#  0.23147399999999999,
#  0.23831799999999997,
#  0.24528699999999998,
#  0.25238,
#  0.2596,
#  0.266946,
# ...

# %%
Data['YY'] = a
Data.head()
# Out:
#      X         Y   y_plus  wedge_height  Nu_t_lsq_n  PHI-Alpha_t_lsq_n  \
# 0  0.0  0.017326  3.11864             0    0.000008           0.000008
# 1  0.0  0.019721  3.54973             0    0.000011           0.000011
# 2  0.0  0.022172  3.99089             0    0.000016           0.000015
# 3  0.0  0.024680  4.44233             0    0.000022           0.000021
# 4  0.0  0.027246  4.90425             0    0.000028           0.000027
#
#       tke_n         dk/dx     dk/dy  dk_dx_i_abs  ...      Vi_AVG_n  Wi_AVG_n  \
# 0  0.002179  6.140000e-08  0.224264     0.224264  ... -5.560000e-10  0.000071
# 1  0.002743  7.220000e-08  0.241222     0.241222  ... -6.470000e-10  0.000081
# 2  0.003357  8.080000e-08  0.253790     0.253790  ... -7.410000e-10  0.000091
# 3  0.004012  8.600000e-08  0.261604     0.261604  ... -8.300000e-10  0.000101
# 4  0.004695  8.720000e-08  0.264527     0.264527  ... -9.060000e-10  0.000112
#
# ...

# %%
data = Data.sort_values(by=['X', 'Y'],inplace =False)
data = data.drop_duplicates(['X','Y'], keep='last')

# %%
data = data.sort_values(by=['X','y_plus'])

# %%
data.head()
# Out:
#            X         Y   y_plus  wedge_height  Nu_t_lsq_n  PHI-Alpha_t_lsq_n  \
# 163240   0.0  0.017326  3.11864             0    0.000008           0.000008
# 163451   0.0  1.982670  3.11864             0    0.000007           0.000008
# 163241   0.0  0.019721  3.54973             0    0.000011           0.000012
# 163450   0.0  1.980280  3.54973             0    0.000011           0.000011
# 1126258  0.0  0.006114  3.60708             0    0.000005           0.000004
#
#             tke_n         dk/dx     dk/dy  dk_dx_i_abs  ...  Ui_AVG_n  \
# 163240   0.002179  6.140000e-08  0.224264     0.224264  ...  0.168031
# 163451   0.002100  5.680000e-08 -0.217273     0.217273  ...  0.166260
# 163241   0.002743  7.220000e-08  0.241222     0.241222  ...  0.190461
# 163450   0.002647  6.720000e-08 -0.234357     0.234357  ...  0.188478
# 1126258  0.002508  2.201890e-04  0.663537     0.663537  ...  0.163296
#
#              Vi_AVG_n  Wi_AVG_n         du/dx     du/dy         dv/dx  \
# ...

# %%
c = pd.DataFrame()
# c['X'] = data['X']
# c['y_plus'] = data['y_plus']
# c = c.reset_index(drop=True)
for i in range(len(data.columns)-4):
    d = []
    for j in range(len(data)//2):
        d.append((data.iloc[2*j][i+4] + data.iloc[2*j+1][i+4])/2)
    c[data.columns[i+4]] = d

c.head()
# Out:
#    Nu_t_lsq_n  PHI-Alpha_t_lsq_n     tke_n         dk/dx     dk/dy  \
# 0    0.000008           0.000008  0.002139  5.910000e-08  0.003495
# 1    0.000011           0.000011  0.002695  6.970000e-08  0.003432
# 2    0.000005           0.000004  0.002493  2.175295e-04  0.004311
# 3    0.000016           0.000016  0.003301  7.830000e-08  0.003207
# 4    0.000007           0.000007  0.003223  6.240000e-05  0.004664
#
#    dk_dx_i_abs  tke_diss_n  PHI-tfe_prod_n  tke_prod_n    PHI-Rp  ...  \
# 0     0.220768   -0.004142        0.000211    0.000668  3.165175  ...
# 1     0.237789   -0.004026        0.000294    0.000947  3.223660  ...
# 2     0.659226   -0.014934        0.001050    0.002938  2.797280  ...
# 3     0.250583   -0.003907        0.000389    0.001283  3.299995  ...
# 4     0.683528   -0.014070        0.001454    0.004250  2.924360  ...
#
#    Ui_AVG_n      Vi_AVG_n  Wi_AVG_n         du/dx    du/dy         dv/dx  \
# ...

# %%
data = data.drop_duplicates(['X','y_plus'], keep='last')
data.head()
# Out:
#            X        Y   y_plus  wedge_height  Nu_t_lsq_n  PHI-Alpha_t_lsq_n  \
# 163451   0.0  1.98267  3.11864             0    0.000007           0.000008
# 163450   0.0  1.98028  3.54973             0    0.000011           0.000011
# 1126699  0.0  1.99389  3.60708             0    0.000005           0.000004
# 163449   0.0  1.97783  3.99089             0    0.000015           0.000016
# 1126698  0.0  1.99283  4.23213             0    0.000007           0.000007
#
#             tke_n         dk/dx     dk/dy  dk_dx_i_abs  ...  Ui_AVG_n  \
# 163451   0.002100  5.680000e-08 -0.217273     0.217273  ...  0.166260
# 163450   0.002647  6.720000e-08 -0.234357     0.234357  ...  0.188478
# 1126699  0.002479  2.148700e-04 -0.654916     0.654916  ...  0.161891
# 163449   0.003245  7.580000e-08 -0.247376     0.247376  ...  0.210884
# 1126698  0.003204  6.090000e-05 -0.678864     0.678864  ...  0.188331
#
#              Vi_AVG_n  Wi_AVG_n         du/dx     du/dy         dv/dx  \
# ...

# %%
data = data.reset_index(drop=True)
data
# Out:
#               X        Y     y_plus  wedge_height  Nu_t_lsq_n  \
# 0        0.0000  1.98267    3.11864             0    0.000007
# 1        0.0000  1.98028    3.54973             0    0.000011
# 2        0.0000  1.99389    3.60708             0    0.000005
# 3        0.0000  1.97783    3.99089             0    0.000015
# 4        0.0000  1.99283    4.23213             0    0.000007
# 5        0.0000  1.97532    4.44233             0    0.000021
# 6        0.0000  1.99176    4.86454             0    0.000010
# 7        0.0000  1.97275    4.90425             0    0.000027
# 8        0.0000  1.97013    5.37688             0    0.000035
# 9        0.0000  1.99067    5.50437             0    0.000014
# 10       0.0000  1.96744    5.86044             0    0.000044
# 11       0.0000  1.98957    6.15172             0    0.000018
# 12       0.0000  1.96469    6.35514             0    0.000055
# 13       0.0000  1.98846    6.80665             0    0.000024
# ...

# %%
c['X'] = data['X']
c['Y'] = data['Y']
c['y_plus'] = data['y_plus']
c
# Out:
#         Nu_t_lsq_n  PHI-Alpha_t_lsq_n     tke_n         dk/dx     dk/dy  \
# 0         0.000008           0.000008  0.002139  5.910000e-08  0.003495
# 1         0.000011           0.000011  0.002695  6.970000e-08  0.003432
# 2         0.000005           0.000004  0.002493  2.175295e-04  0.004311
# 3         0.000016           0.000016  0.003301  7.830000e-08  0.003207
# 4         0.000007           0.000007  0.003223  6.240000e-05  0.004664
# 5         0.000021           0.000022  0.003948  8.380000e-08  0.002826
# 6         0.000010           0.000010  0.003971 -8.235000e-05  0.004803
# 7         0.000028           0.000029  0.004624  8.545000e-08  0.002312
# 8         0.000036           0.000037  0.005319  8.300000e-08  0.001694
# 9         0.000014           0.000014  0.004713 -2.068905e-04  0.004723
# 10        0.000045           0.000046  0.006019  7.650000e-08  0.001010
# 11        0.000018           0.000018  0.005426  8.200000e-08  0.004457
# ...

# %%
c
# Out:
#         Nu_t_lsq_n  PHI-Alpha_t_lsq_n     tke_n         dk/dx     dk/dy  \
# 0         0.000008           0.000008  0.002139  5.910000e-08  0.003495
# 1         0.000011           0.000011  0.002695  6.970000e-08  0.003432
# 2         0.000005           0.000004  0.002493  2.175295e-04  0.004311
# 3         0.000016           0.000016  0.003301  7.830000e-08  0.003207
# 4         0.000007           0.000007  0.003223  6.240000e-05  0.004664
# 5         0.000021           0.000022  0.003948  8.380000e-08  0.002826
# 6         0.000010           0.000010  0.003971 -8.235000e-05  0.004803
# 7         0.000028           0.000029  0.004624  8.545000e-08  0.002312
# 8         0.000036           0.000037  0.005319  8.300000e-08  0.001694
# 9         0.000014           0.000014  0.004713 -2.068905e-04  0.004723
# 10        0.000045           0.000046  0.006019  7.650000e-08  0.001010
# 11        0.000018           0.000018  0.005426  8.200000e-08  0.004457
# ...

# %%
c.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_all_Re.csv',header=True,index=False)

# %%
data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (3)\mean_orig_channel_all_Re.csv')
# data = data.sort_values(by=['Y'])

# %%
data
# Out:
#         Unnamed: 0        X         Y     y_plus  wedge_height  Nu_t_lsq_n  \
# 0                0  0.00000  0.017326    3.11864           0.0    0.000008
# 1                1  0.00000  0.019721    3.54973           0.0    0.000011
# 2                2  0.00000  0.022172    3.99089           0.0    0.000016
# 3                3  0.00000  0.024680    4.44233           0.0    0.000021
# 4                4  0.00000  0.027246    4.90425           0.0    0.000028
# 5                5  0.00000  0.029872    5.37688           0.0    0.000036
# 6                6  0.00000  0.032558    5.86044           0.0    0.000045
# 7                7  0.00000  0.035306    6.35514           0.0    0.000056
# 8                8  0.00000  0.038118    6.86120           0.0    0.000069
# 9                9  0.00000  0.040994    7.37886           0.0    0.000083
# 10              10  0.00000  0.043935    7.90835           0.0    0.000099
# ...
