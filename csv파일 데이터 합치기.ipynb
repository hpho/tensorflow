# %%
#import scipy.io
import pandas as pd

# %%
data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\origin_wedge_Re180_Pr2_0.csv')
data1 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\origin_wedge_Re400_Pr2_0.csv')
data2 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\origin_wedge_Re590_Pr2_0.csv')
print(data.shape)
print(data1.shape)
print(data2.shape)
full_data = pd.concat([data,data1,data2])
print(full_data.shape)
full_data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_wedge_all_Re_Pr2_0.csv',header=True,index=False)
# Out:
# (90655, 55)
# (197079, 55)
# (199207, 55)
# (486941, 55)

# %%
data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\uniform_channel_Re180.csv')
data1 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\uniform_channel_Re400.csv')
data2 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\uniform_channel_Re590.csv')
print(data.shape)
print(data1.shape)
print(data2.shape)
full_data = pd.concat([data,data1,data2])
print(full_data.shape)
full_data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\uniform_channel_all_Re.csv',header=True,index=False)
# Out:
# (567120, 55)
# (540318, 55)
# (575460, 55)
# (1682898, 55)

# %%
data = pd.read_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re400_Pr0_2.csv')
data1 = pd.read_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re400_Pr0_7.csv')
data2 = pd.read_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re400_Pr2.csv')
print(data.shape)
print(data1.shape)
print(data2.shape)
full_data = pd.concat([data,data1,data2])
print(full_data.shape)
full_data.to_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\x_y_yp_wedge_not_included\uniform_channel_Re400.csv',header=True,index=False)
# Out:
# (190430, 55)
# (190430, 55)
# (190430, 55)
# (571290, 55)

# %%
data = pd.read_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re590_Pr0_2.csv')
data1 = pd.read_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re590_Pr0_7.csv')
data2 = pd.read_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re590_Pr2.csv')
print(data.shape)
print(data1.shape)
print(data2.shape)
full_data = pd.concat([data,data1,data2])
print(full_data.shape)
full_data.to_csv(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\x_y_yp_wedge_not_included\uniform_channel_Re590.csv',header=True,index=False)
# Out:
# (191820, 55)
# (191820, 55)
# (191820, 55)
# (575460, 55)

# %%
full_data1 = list(full_data)

# %%
scipy.io.savemat(r'D:\Desktop\190305\csvfile\new\full.mat',full_data)

# %%
full_data.to_csv(r'D:\Desktop\190305\csvfile\new\uniform_wedge_Re180.csv',header=True,index=False)

# %%
data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re180_Pr0_2.csv')
data1 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re180_Pr0_7.csv')
data2 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re180_Pr2_0.csv')

print(data.shape)
print(data1.shape)
print(data2.shape)

full_data = pd.concat([data,data1,data2])
print(full_data.shape)

full_data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_wedge_Re180.csv',header=True,index=False)
# Out:
# (90655, 55)
# (90655, 55)
# (90655, 55)
# (271965, 55)

# %%
data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re590_Pr0_2.csv')
data1 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re590_Pr0_7.csv')
data2 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re590_Pr2_0.csv')

print(data.shape)
print(data1.shape)
print(data2.shape)

full_data = pd.concat([data,data1,data2])
print(full_data.shape)

full_data.to_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re590.csv',header=True,index=False)
# Out:
# (199429, 55)
# (199429, 55)
# (199429, 55)
# (598287, 55)

# %%
data = pd.read_excel(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re180_Pr0_2.xlsx',sheet_name='Sheet1')
data1 = pd.read_excel(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re180_Pr0_7.xlsx',sheet_name='Sheet1')
data2 = pd.read_excel(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re180_Pr2.xlsx',sheet_name='Sheet1')

print(data.shape)
print(data1.shape)
print(data2.shape)

#full_data = pd.concat([data,data1,data2])
#print(full_data.shape)

#full_data.to_csv(r'D:\Desktop\190305\csvfile\new\ununiform_wedge_Re590.csv',header=True,index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-638987511b45> in <module>
#       1 data = pd.read_excel(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re180_Pr0_2.xlsx',sheet_name='Sheet1')
# ----> 2 data1 = pd.read_excel(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re180_Pr0_7.xlsx',sheet_name='Sheet1')
#       3 data2 = pd.read_excel(r'C:\Users\user\SynologyDrive\journal paper\Taeksoo Kim\csv_data\uniform_channel_Re180_Pr2.xlsx',sheet_name='Sheet1')
#       4
#       5 print(data.shape)
#
# ~\Anaconda\envs\tensorflow\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
# ...

# %%
data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\origin_wedge_Re180_Pr2_0.csv')
data1 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\origin_wedge_Re400_Pr2_0.csv')
#data2 = pd.read_csv(r'D:\Desktop\190305\csvfile\new\origin_wedge_Re590_Pr2_0.csv')
print(data.shape)
print(data1.shape)
#print(data2.shape)
full_data = pd.concat([data,data1])
print(full_data.shape)
full_data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_wedge_exclude_Re_590.csv',header=True,index=False)
# Out:
# (90655, 55)
# (197079, 55)
# (287734, 55)

# %%
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_wedge_all_Re.csv')
Data = Data[Data.Pr < 2]
Data
# Out:
#                     X         Y    y_plus  wedge_height  Nu_t_lsq   Alpha_t  \
# 0       -5.000000e-09 -0.076720   3.17154           0.1  0.000022  0.000022
# 1       -5.000000e-09 -0.074086   3.19995           0.1  0.000029  0.000028
# 2       -5.000000e-09 -0.071392   3.68864           0.1  0.000039  0.000036
# 3       -5.000000e-09 -0.068635   4.26446           0.1  0.000050  0.000046
# 4       -5.000000e-09 -0.065814   4.27626           0.1  0.000063  0.000057
# 5       -5.000000e-09 -0.062928   4.92322           0.1  0.000077  0.000069
# 6       -5.000000e-09 -0.059976   4.92252           0.1  0.000094  0.000083
# 7       -5.000000e-09 -0.056957   5.66984           0.1  0.000113  0.000099
# 8       -5.000000e-09 -0.053868   5.65290           0.1  0.000135  0.000117
# 9       -5.000000e-09 -0.050709   6.51552           0.1  0.000159  0.000137
# 10      -5.000000e-09 -0.047478   6.47769           0.1  0.000186  0.000160
# ...

# %%
Data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_wedge_exclude_Pr_2_0.csv',header=True, index=False)

# %%
#import pandas as pd
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_wedge_all_Re.csv')
Data = Data[Data.Re < 590]
Data = Data[Data.Pr < 2.0]
Data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_wedge_low_Re_Pr.csv',header=True, index=False)

# %%
#import pandas as pd
Data = pd.read_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_all_Re.csv')
Data = Data[Data.Re < 590]
Data = Data[Data.Pr < 2.0]
Data.to_csv(r'D:\Desktop\190305\csvfile\new\새 폴더 (2)\orig_channel_low_Re_Pr.csv',header=True, index=False)
